# %%
import numpy as np
import matplotlib.pyplot as plt
from paths import *

# %%
lcpath_final = Base_Dir + f"Data/LC10/proc/RsRp_2_3/Binned_LC/light_curves_all_processed.npy"
lcs = np.load(lcpath_final)

idx = 0
plt.plot(lcs[idx])
plt.show()
